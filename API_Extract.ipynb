# %% [markdown]
# # Extract API Data

# %% [markdown]
# ## Objectives
#
# In this part I have:
#
# *   Collected exchange rate data using an API
# *   Stored the data as a CSV

# %%
# !mamba install pandas==1.3.3 -y
# !mamba install requests==2.26.0 -y
# !mamba install bs4==4.10.0 -y
# !mamba install html5lib==1.1 -y
# !pip install lxml==4.6.4
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pandas==1.3.3']
#
# pkgs/r/noarch            [<=>                 ] (00m:00s)
# pkgs/r/noarch            [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/main/linux-64       [<=>                 ] (00m:00s)
# pkgs/r/noarch            [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/main/noarch         [<=>                 ] (00m:00s)
# pkgs/r/noarch            [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/r/linux-64          [<=>                 ] (00m:00s)
# pkgs/r/noarch            [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/main/noarch         [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 436 KB / ?? (1.41 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/main/noarch         [<=>                 ] (00m:00s) Finalizing...
# pkgs/r/linux-64          [=>                ] (00m:00s) 436 KB / ?? (1.41 MB/s)
# pkgs/r/noarch            [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/main/noarch         [<=>                 ] (00m:00s) Done
# pkgs/r/linux-64          [=>                ] (00m:00s) 436 KB / ?? (1.41 MB/s)
# pkgs/main/noarch         [====================] (00m:00s) Done
# pkgs/r/noarch            [=>                ] (00m:00s) 440 KB / ?? (1.42 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 436 KB / ?? (1.41 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 436 KB / ?? (1.41 MB/s)
# pkgs/r/noarch            [<=>                 ] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 436 KB / ?? (1.41 MB/s)
# pkgs/r/noarch            [====================] (00m:00s) Done
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/r/linux-64          [=>                ] (00m:00s) 436 KB / ?? (1.41 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/r/linux-64          [<=>               ] (00m:00s) 436 KB / ?? (1.41 MB/s)
# pkgs/main/linux-64       [=>                ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) 1 MB / ?? (2.64 MB/s)
# pkgs/main/linux-64       [<=>               ] (00m:00s) 476 KB / ?? (1.53 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) 1 MB / ?? (2.64 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.84 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) 1 MB / ?? (2.64 MB/s)
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.84 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.84 MB/s)
# pkgs/r/linux-64          [ <=>                ] (00m:00s) Done
# pkgs/r/linux-64          [====================] (00m:00s) Done
# pkgs/main/linux-64       [ <=>                ] (00m:00s) 1 MB / ?? (2.84 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 1 MB / ?? (2.84 MB/s)
# pkgs/main/linux-64       [  <=>               ] (00m:00s) 2 MB / ?? (3.33 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 2 MB / ?? (3.33 MB/s)
# pkgs/main/linux-64       [   <=>              ] (00m:00s) 3 MB / ?? (3.52 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 3 MB / ?? (3.52 MB/s)
# pkgs/main/linux-64       [    <=>             ] (00m:00s) 3 MB / ?? (3.68 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 3 MB / ?? (3.68 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) 4 MB / ?? (3.79 MB/s)
# pkgs/main/linux-64       [     <=>            ] (00m:00s) Finalizing...
# pkgs/main/linux-64       [     <=>            ] (00m:01s) Done
# pkgs/main/linux-64       [====================] (00m:01s) Done
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - pandas==1.3.3
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build           Channel                  Size
# ────────────────────────────────────────────────────────────────────────────────
#   Change:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - openssl              1.1.1q  h166bdaf_0      installed
#   + openssl              1.1.1q  h7f8727e_0      pkgs/main/linux-64       3 MB
#
#   Upgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates   2022.9.14  ha878542_0      installed
#   + ca-certificates  2022.10.11  h06a4308_0      pkgs/main/linux-64     124 KB
#   - certifi           2022.9.14  pyhd8ed1ab_0    installed
#   + certifi           2022.9.24  py37h06a4308_0  pkgs/main/linux-64     154 KB
#
#   Downgrade:
# ────────────────────────────────────────────────────────────────────────────────
#
#   - pandas                1.3.5  py37h8c16a72_0  installed
#   + pandas                1.3.3  py37h8c16a72_0  pkgs/main/linux-64       9 MB
#
#   Summary:
#
#   Change: 1 packages
#   Upgrade: 2 packages
#   Downgrade: 1 packages
#
#   Total download: 12 MB
#
# ────────────────────────────────────────────────────────────────────────────────
#
# Downloading  [>                                        ] (00m:00s)    3.43 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)    3.43 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  808.43 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished ca-certificates                      (00m:00s)             124 KB    807 KB/s
# Downloading  [>                                        ] (00m:00s)  808.43 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  808.43 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  808.43 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [>                                        ] (00m:00s)  808.43 KB/s
# Extracting   [==========>                              ] (00m:00s)        1 / 4
# Downloading  [>                                        ] (00m:00s)    1.57 MB/s
# Extracting   [==========>                              ] (00m:00s)        1 / 4
# Finished certifi                              (00m:00s)             154 KB    887 KB/s
# Downloading  [>                                        ] (00m:00s)    1.57 MB/s
# Extracting   [==========>                              ] (00m:00s)        1 / 4
# Downloading  [>                                        ] (00m:00s)    1.57 MB/s
# Extracting   [==========>                              ] (00m:00s)        1 / 4
# Downloading  [>                                        ] (00m:00s)    1.57 MB/s
# Extracting   [==========>                              ] (00m:00s)        1 / 4
# Downloading  [>                                        ] (00m:00s)    1.57 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [=========>                               ] (00m:00s)   13.32 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Finished openssl                              (00m:00s)               3 MB     12 MB/s
# Downloading  [=========>                               ] (00m:00s)   13.32 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [=========>                               ] (00m:00s)   13.32 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [=========>                               ] (00m:00s)   13.32 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [=====================================>   ] (00m:00s)   36.95 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [=====================================>   ] (00m:00s)   36.95 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [=========================================] (00m:00s)   39.55 MB/s
# Extracting   [====================>                    ] (00m:00s)        2 / 4
# Downloading  [=========================================] (00m:00s)   39.55 MB/s
# Extracting   [==============================>          ] (00m:00s)        3 / 4
# Finished pandas                               (00m:00s)               9 MB     30 MB/s
# Downloading  [=========================================] (00m:00s)   39.55 MB/s
# Extracting   [==============================>          ] (00m:00s)        3 / 4
# Downloading  [=========================================] (00m:00s)   39.55 MB/s
# Extracting   [==============================>          ] (00m:00s)        3 / 4
# Downloading  [=========================================] (00m:00s)   39.55 MB/s
# Extracting   [==============================>          ] (00m:00s)        3 / 4
# Downloading  [=========================================] (00m:00s)   39.55 MB/s
# Extracting   [=========================================] (00m:00s)        4 / 4
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['requests==2.26.0']
#
# pkgs/main/linux-64       Using cache
# pkgs/main/noarch         Using cache
# pkgs/r/linux-64          Using cache
# pkgs/r/noarch            Using cache
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - requests==2.26.0
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package               Version  Build         Channel               Size
# ───────────────────────────────────────────────────────────────────────────
#   Downgrade:
# ───────────────────────────────────────────────────────────────────────────
#
#   - charset-normalizer    2.1.1  pyhd8ed1ab_0  installed
#   + charset-normalizer    2.0.4  pyhd3eb1b0_0  pkgs/main/noarch     35 KB
#   - requests             2.28.1  pyhd8ed1ab_1  installed
#   + requests             2.26.0  pyhd3eb1b0_0  pkgs/main/noarch     59 KB
#
#   Summary:
#
#   Downgrade: 2 packages
#
#   Total download: 94 KB
#
# ───────────────────────────────────────────────────────────────────────────
#
# Downloading  [==============>                          ] (00m:00s)  228.76 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished charset-normalizer                   (00m:00s)              35 KB    228 KB/s
# Downloading  [==============>                          ] (00m:00s)  228.76 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==============>                          ] (00m:00s)  228.76 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==============>                          ] (00m:00s)  228.76 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  617.12 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished requests                             (00m:00s)              59 KB    395 KB/s
# Downloading  [=========================================] (00m:00s)  617.12 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  617.12 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=========================================] (00m:00s)  617.12 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  617.12 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  617.12 KB/s
# Extracting   [=========================================] (00m:00s)        2 / 2
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['bs4==4.10.0']
#
# pkgs/main/linux-64       Using cache
# pkgs/r/linux-64          [>                   ] (--:--) No change
# pkgs/r/linux-64          [====================] (00m:00s) No change
# pkgs/r/noarch            [>                   ] (--:--) No change
# pkgs/r/noarch            [====================] (00m:00s) No change
# pkgs/main/noarch         [>                   ] (--:--) No change
# pkgs/main/noarch         [====================] (00m:00s) No change
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - bs4==4.10.0
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package           Version  Build         Channel               Size
# ───────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────
#
#   + bs4              4.10.0  hd3eb1b0_0    pkgs/main/noarch     10 KB
#
#   Downgrade:
# ───────────────────────────────────────────────────────────────────────
#
#   - beautifulsoup4   4.11.1  pyha770c72_0  installed
#   + beautifulsoup4   4.10.0  pyh06a4308_0  pkgs/main/noarch     85 KB
#
#   Summary:
#
#   Install: 1 packages
#   Downgrade: 1 packages
#
#   Total download: 95 KB
#
# ───────────────────────────────────────────────────────────────────────
#
# Downloading  [====================================>    ] (00m:00s)  586.98 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished beautifulsoup4                       (00m:00s)              85 KB    586 KB/s
# Downloading  [====================================>    ] (00m:00s)  586.98 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [====================================>    ] (00m:00s)  586.98 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [====================================>    ] (00m:00s)  586.98 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [====================================>    ] (00m:00s)  586.98 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [====================================>    ] (00m:00s)  538.25 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [====================================>    ] (00m:00s)  538.25 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  598.30 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Finished bs4                                  (00m:00s)              10 KB     63 KB/s
# Downloading  [=========================================] (00m:00s)  598.30 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  598.30 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  598.30 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  598.30 KB/s
# Extracting   [=========================================] (00m:00s)        2 / 2
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (0.15.3) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['html5lib==1.1']
#
# pkgs/main/noarch         Using cache
# pkgs/r/linux-64          Using cache
# pkgs/r/noarch            Using cache
# pkgs/main/linux-64       [>                   ] (--:--) No change
# pkgs/main/linux-64       [====================] (00m:00s) No change
#
# Pinned packages:
#   - python 3.7.*
#
#
# Transaction
#
#   Prefix: /home/jupyterlab/conda/envs/python
#
#   Updating specs:
#
#    - html5lib==1.1
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package         Version  Build         Channel                 Size
# ───────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────
#
#   + html5lib          1.1  pyhd3eb1b0_0  pkgs/main/noarch       91 KB
#   + webencodings    0.5.1  py37_1        pkgs/main/linux-64     19 KB
#
#   Summary:
#
#   Install: 2 packages
#
#   Total download: 110 KB
#
# ───────────────────────────────────────────────────────────────────────
#
# Downloading  [==============>                          ] (00m:00s)  269.81 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [==============>                          ] (00m:00s)  269.81 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=================================>       ] (00m:00s)  601.47 KB/s
# Extracting   [>                                                      ] (--:--)
# Finished html5lib                             (00m:00s)              91 KB    601 KB/s
# Downloading  [=================================>       ] (00m:00s)  601.47 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=================================>       ] (00m:00s)  601.47 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=================================>       ] (00m:00s)  601.47 KB/s
# Extracting   [>                                                      ] (--:--)
# Downloading  [=================================>       ] (00m:00s)  601.47 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  432.74 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Finished webencodings                         (00m:00s)              19 KB     75 KB/s
# Downloading  [=========================================] (00m:00s)  432.74 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  432.74 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  432.74 KB/s
# Extracting   [====================>                    ] (00m:00s)        1 / 2
# Downloading  [=========================================] (00m:00s)  432.74 KB/s
# Extracting   [=========================================] (00m:00s)        2 / 2
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting lxml==4.6.4
#   Downloading lxml-4.6.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 77.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: lxml
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.1
#     Uninstalling lxml-4.9.1:
#       Successfully uninstalled lxml-4.9.1
# Successfully installed lxml-4.6.4

# %% [markdown]
# ## Imports
#
# Import any additional libraries you may need here.

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET  # this module helps in processing XML files.
import requests
import json
from datetime import datetime

# %% [markdown]
# ## Extract Data Using an API

# %% [markdown]
# Using ExchangeRate-API we will extract currency exchange rate data. Use the below steps to get the access key and to get the data.
#
# 1.  Open the url : [https://exchangeratesapi.io/](https://exchangeratesapi.io/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) and click on **Get Free API Key**.
# 2.  Subscribe for Free plan and Sign-in with the Google Account.
# 3.  Once the account is created you will be redirected to [https://apilayer.com](https://apilayer.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0221ENSkillsNetwork23455645-2022-01-01) website.
# 4.  Now, click on the **user icon** and click **Account** as shown below:
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0221EN-SkillsNetwork/labs/module%206/Final%20Assignment/Images/account.png"/>
#
# 3.  Scroll down and you will get the API Key section. Copy the API key and use in the url in Question 1.

# %% [markdown]
# ### Call the API
#
# Using the `requests` library call the endpoint given above and save the text:

# %%
# Write your code here
url = "https://api.apilayer.com/exchangerates_data/latest?base=EUR&apikey=EnpHTPMP3mpnXHGPLOQ71Kqkg4f7SzOR" #Make sure to change ******* to your API key.
data = requests.get(url)
results = json.loads(data.text)
print(results)
# Out:
# {'success': True, 'timestamp': 1667231104, 'base': 'EUR', 'date': '2022-10-31', 'rates': {'AED': 3.627322, 'AFN': 85.446977, 'ALL': 117.130725, 'AMD': 390.480331, 'ANG': 1.780912, 'AOA': 478.792151, 'ARS': 154.943446, 'AUD': 1.547663, 'AWG': 1.780097, 'AZN': 1.673621, 'BAM': 1.944903, 'BBD': 1.979797, 'BDT': 100.098419, 'BGN': 1.952928, 'BHD': 0.372352, 'BIF': 2025.50897, 'BMD': 0.987571, 'BND': 1.399132, 'BOB': 6.823134, 'BRL': 5.173093, 'BSD': 0.988158, 'BTC': 4.8486068e-05, 'BTN': 81.840117, 'BWP': 13.299314, 'BYN': 2.496573, 'BYR': 19356.39971, 'BZD': 1.981119, 'CAD': 1.349106, 'CDF': 2014.645208, 'CHF': 0.990692, 'CLF': 0.033777, 'CLP': 932.010814, 'CNY': 7.212136, 'COP': 4829.797005, 'CRC': 610.48459, 'CUC': 0.987571, 'CUP': 26.170642, 'CVE': 109.966113, 'CZK': 24.482023, 'DJF': 175.908113, 'DKK': 7.441656, 'DOP': 53.328734, 'DZD': 138.820976, 'EGP': 23.851585, 'ERN': 14.813571, 'ETB': 52.727618, 'EUR': 1, 'FJD': 2.287708, 'FKP': 0.871556, 'GBP': 0.859153, 'GEL': 2.730612, 'GGP': 0.871556, 'GHS': 13.875847, 'GIP': 0.871556, 'GMD': 57.32863, 'GNF': 8591.871082, 'GTQ': 7.74208, 'GYD': 206.700762, 'HKD': 7.75205, 'HNL': 24.426391, 'HRK': 7.531716, 'HTG': 127.739367, 'HUF': 409.258472, 'IDR': 15440.432161, 'ILS': 3.480582, 'IMP': 0.871556, 'INR': 81.792617, 'IQD': 1441.854264, 'IRR': 41873.028348, 'ISK': 143.313317, 'JEP': 0.871556, 'JMD': 151.515885, 'JOD': 0.701078, 'JPY': 146.948704, 'KES': 119.890148, 'KGS': 82.466562, 'KHR': 4091.649268, 'KMF': 488.896887, 'KPW': 888.814136, 'KRW': 1411.00277, 'KWD': 0.30591, 'KYD': 0.823482, 'KZT': 461.70659, 'LAK': 16714.64611, 'LBP': 1503.084035, 'LKR': 361.164585, 'LRD': 151.715635, 'LSL': 17.716831, 'LTL': 2.916041, 'LVL': 0.597372, 'LYD': 4.908508, 'MAD': 10.729998, 'MDL': 19.055147, 'MGA': 4226.765078, 'MKD': 61.259036, 'MMK': 2075.038256, 'MNT': 3318.017906, 'MOP': 7.988697, 'MRO': 352.562825, 'MUR': 43.40325, 'MVR': 15.210578, 'MWK': 1017.926175, 'MXN': 19.596088, 'MYR': 4.663808, 'MZN': 63.036651, 'NAD': 17.717214, 'NGN': 432.902252, 'NIO': 35.568521, 'NOK': 10.282974, 'NPR': 130.941328, 'NZD': 1.708, 'OMR': 0.38024, 'PAB': 0.988123, 'PEN': 3.934975, 'PGK': 3.482469, 'PHP': 57.514674, 'PKR': 217.636052, 'PLN': 4.707476, 'PYG': 7194.46921, 'QAR': 3.5955, 'RON': 4.909513, 'RSD': 117.308667, 'RUB': 60.930818, 'RWF': 1054.595523, 'SAR': 3.710957, 'SBD': 8.101755, 'SCR': 14.349132, 'SDG': 564.890674, 'SEK': 10.920871, 'SGD': 1.398742, 'SHP': 1.360284, 'SLL': 16961.539227, 'SOS': 562.3982, 'SRD': 28.772871, 'STD': 20440.734366, 'SVC': 8.646508, 'SYP': 2481.302838, 'SZL': 18.164429, 'THB': 37.596861, 'TJS': 9.955166, 'TMT': 3.4565, 'TND': 3.184901, 'TOP': 2.389379, 'TRY': 18.38354, 'TTD': 6.701019, 'TWD': 31.862508, 'TZS': 2303.016799, 'UAH': 36.491606, 'UGX': 3754.695455, 'USD': 0.987571, 'UYU': 40.30098, 'UZS': 11044.764496, 'VND': 24541.149632, 'VUV': 123.594455, 'WST': 2.809578, 'XAF': 652.29872, 'XAG': 0.051506, 'XAU': 0.000603, 'XCD': 2.668961, 'XDR': 0.768788, 'XOF': 652.256029, 'XPF': 118.65691, 'YER': 247.139964, 'ZAR': 18.131436, 'ZMK': 8889.332105, 'ZMW': 16.11346, 'ZWL': 317.997592}}

# %% [markdown]
# ### Save as DataFrame
#
#  Using the data gathered turn it into a `pandas` dataframe.

# %%
# Turn the data into a dataframe
df=pd.DataFrame(results)
df
# Out:
#      success   timestamp base        date        rates
# AED     True  1667231104  EUR  2022-10-31     3.627322
# AFN     True  1667231104  EUR  2022-10-31    85.446977
# ALL     True  1667231104  EUR  2022-10-31   117.130725
# AMD     True  1667231104  EUR  2022-10-31   390.480331
# ANG     True  1667231104  EUR  2022-10-31     1.780912
# ..       ...         ...  ...         ...          ...
# YER     True  1667231104  EUR  2022-10-31   247.139964
# ZAR     True  1667231104  EUR  2022-10-31    18.131436
# ZMK     True  1667231104  EUR  2022-10-31  8889.332105
# ZMW     True  1667231104  EUR  2022-10-31    16.113460
# ZWL     True  1667231104  EUR  2022-10-31   317.997592
#
# [167 rows x 5 columns]

# %%
# Drop unnescessary columns
df.drop(df.iloc[:, 1:3], inplace=True, axis=1)
# Remove all columns between column index 1 to 3
df
# Out:
#            rates
# AED     3.627322
# AFN    85.446977
# ALL   117.130725
# AMD   390.480331
# ANG     1.780912
# ..           ...
# YER   247.139964
# ZAR    18.131436
# ZMK  8889.332105
# ZMW    16.113460
# ZWL   317.997592
#
# [167 rows x 1 columns]

# %% [markdown]
# ### Load the Data
#
# Using the dataframe save it as a CSV names `exchange_rates_1.csv`.

# %%
# Save the Dataframe
df.to_csv('exchange_rates_1.csv')

# %% [markdown]
# ## Authors

# %% [markdown]
# Mohammed Badruddin Saad
